# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('zomato.csv')

# %%
df.sample(5)
# Out:
#                                                      url  \
# 36566  https://www.zomato.com/bangalore/watheen-nuts-...
# 14339  https://www.zomato.com/bangalore/kairali-resta...
# 1684   https://www.zomato.com/bangalore/ministry-of-b...
# 35050  https://www.zomato.com/bangalore/mad-over-donu...
# 986    https://www.zomato.com/bangalore/biryani-durba...
#
#                                                  address                name  \
# 36566  01, 100 Feet Ring Road, 1st Phase, BTM 2nd sta...        Watheen Nuts
# 14339  Vinayak Nagar, Opposite Electro Park Apartment...  Kairali Restaurant
# 1684   No 121/1, Abhinandana Complex, Manipal Country...  Ministry of Burger
# 35050  G 6, Ground Floor, Money Centre, 80 Feet Road,...     Mad Over Donuts
# 986    452, 2nd Main, 8th Cross, Lakshmi Layout, Mico...      Biryani Durbar
#
#       online_order book_table    rate  votes  \
# 36566           No         No     NaN      0
# 14339          Yes         No   3.4/5     19
# ...

# %%
print('shape of data: row and columns',*df.shape),
#df.columns

pd.DataFrame(data=[df.isnull().sum(),df.nunique(),df.isnull().sum()/51717*100]).T
# Out:
# shape of data: row and columns 51717 17
#                                    0        1          2
# url                              0.0  51717.0   0.000000
# address                          0.0  11495.0   0.000000
# name                             0.0   8792.0   0.000000
# online_order                     0.0      2.0   0.000000
# book_table                       0.0      2.0   0.000000
# rate                          7775.0     64.0  15.033741
# votes                            0.0   2328.0   0.000000
# phone                         1208.0  14926.0   2.335789
# location                        21.0     93.0   0.040606
# rest_type                      227.0     93.0   0.438927
# dish_liked                   28078.0   5271.0  54.291626
# cuisines                        45.0   2723.0   0.087012
# approx_cost(for two people)    346.0     70.0   0.669026
# reviews_list                     0.0  22513.0   0.000000
# menu_item                        0.0   9098.0   0.000000
# ...

# %%
# first remove the redundant column 
df.drop(['dish_liked','phone','url','name'],axis=1)
# Out:
#                                                  address online_order  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...          Yes
# 2      1112, Next to KIMS Medical College, 17th Cross...          Yes
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...           No
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...           No
# ...                                                  ...          ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...           No
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...           No
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...           No
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...           No
# 51716  ITPL Main Road, KIADB Export Promotion Industr...           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# ...

# %%
for i in range(20,50):
    print(*df.loc[i,['address','listed_in(city)']],sep='----')
# Out:
# 146, 50 ft Road, 3rd Phase, 3rd Stage, Near Katriguppe Water Tank Circle, Banashankari, Bangalore----Banashankari
# 3353, 2nd Cross, Opposite Auden School, Hoskerehalli Cross, 3rd Stage, Banashankari, Bangalore----Banashankari
# SRF Complex, Near BDA Complex, Kathreguppe Main Road, Banashankari, Bangalore----Banashankari
# 224/Y, 4th Phase, 7th Block, 100 Feet Ring Road, Near Kamakya Theatre, Banashankari, Bangalore----Banashankari
# 775/1, Opposite Gupta Collage, 7th Block, 3rd Stage, Banashankari, Bangalore----Banashankari
# 101, Water Tank Road, 2nd Block, 3rd Stage, Banashankari, Bangalore----Banashankari
# 27th Cross Rd, Banashankari Stage II, Banashankari, Bangalore----Banashankari
# 1036, Srinidhi Plaza, 3rd floor, Above Nilgiris, Stage 2, Banashankari, Bangalore----Banashankari
# 940, Shantha Complex, 20th Main, 2nd Stage, Banashankari, Bangalore----Banashankari
# 112, Bull Temple Road,next to more Basavanagudi, Bangalore----Banashankari
# ...
