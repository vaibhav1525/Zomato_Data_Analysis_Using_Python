# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

dataset = pd.read_csv('zomato.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DataFrame (replace with your actual data)
data = {'restaurant_rating': [3.5, 4.2, 2.8, 4.8, 3.9, 'NA', 4.1, 3.6, 2.9, 4.5, 3.3]}
df = pd.DataFrame(data)

df['restaurant_rating'] = pd.to_numeric(df['restaurant_rating'], errors='coerce'
plt.hist(df['restaurant_rating'].dropna(), bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Restaurant Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
# Out:
# '\nThis distribution shows the frequency of restaurants within different rating ranges.\nThe plot indicates that a significant number of restaurants are rated between 3.5 and 4.0.\nWhile this isn\'t necessarily "bad," it suggests there\'s room for improvement for many restaurants.\nA higher average rating (closer to or above 4.0) would generally be desirable.\nRestaurants on the platform might consider strategies to improve their service and customer satisfaction\nto achieve higher ratings. Further analysis could explore factors contributing to lower ratings.\n'
